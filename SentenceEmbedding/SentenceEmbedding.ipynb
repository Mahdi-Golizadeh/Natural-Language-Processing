# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Golizadeh/Natural-Language-Processing/blob/main/SentenceEmbedding/SentenceEmbedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 3.8 MB/s eta 0:00:00

# %%
# Here is some code that suppresses warning messages.
from transformers.utils import logging
logging.set_verbosity_error()

# %%
# Build the sentence embedding pipeline using
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
sentences1 = ['The cat sat on the mat',
              'A boy is playing videogame',
              'The food was delicious']

# %%
embeddings1 = model.encode(sentences1,
                           convert_to_tensor=True)
print(embeddings1)
# Out:
# tensor([[ 0.1304, -0.0119, -0.0281,  ...,  0.0446,  0.0004,  0.0522],
#         [ 0.0070,  0.0284, -0.0468,  ...,  0.0149, -0.0004, -0.0252],
#         [-0.0316,  0.0845,  0.0141,  ...,  0.0503,  0.0252, -0.0305]])

# %%
sentences2 = ['The dog eats bone',
              'A woman watches TV',
              'the resturant was awful']
embeddings2 = model.encode(sentences2,
                           convert_to_tensor=True)
print(embeddings2)
# Out:
# tensor([[-0.0225, -0.0044,  0.0741,  ...,  0.0478,  0.0327,  0.0136],
#         [ 0.0054, -0.0920,  0.0140,  ...,  0.0167, -0.0086, -0.0424],
#         [ 0.0726,  0.0561, -0.0042,  ...,  0.0161, -0.0593,  0.0298]])

# %%
# Calculate the cosine similarity between two sentences as a measure of how similar they are to each other.
from sentence_transformers import util

# %%
cosine_scores = util.cos_sim(embeddings1,embeddings2)
print(cosine_scores)
# Out:
# tensor([[ 0.2148,  0.0808,  0.0760],
#         [ 0.0535,  0.0379, -0.1502],
#         [ 0.2177, -0.0645,  0.3730]])

# %%
for i in range(len(sentences1)):
    for j in range(len(sentences1)):
        print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i],
                                                    sentences2[j],
                                                    cosine_scores[i][j]))
# Out:
# The cat sat on the mat 		 The dog eats bone 		 Score: 0.2148
# The cat sat on the mat 		 A woman watches TV 		 Score: 0.0808
# The cat sat on the mat 		 the resturant was awful 		 Score: 0.0760
# A boy is playing videogame 		 The dog eats bone 		 Score: 0.0535
# A boy is playing videogame 		 A woman watches TV 		 Score: 0.0379
# A boy is playing videogame 		 the resturant was awful 		 Score: -0.1502
# The food was delicious 		 The dog eats bone 		 Score: 0.2177
# The food was delicious 		 A woman watches TV 		 Score: -0.0645
# The food was delicious 		 the resturant was awful 		 Score: 0.3730
